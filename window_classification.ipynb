# %% [markdown]
# ### Wikipedia gold standard (WG) corpus
# * PER(Person)
# * LOC(Location)
# * ORG(Organization)
# * MISC(Miscellaneous, 이것저것 다양한)
#
# http://downloads.schwa.org/wikiner/wikigold.conll.txt

# %%
import numpy as np
import random
from scipy.special import expit # expit for sigmoid function.
from pprint import pprint
from preprocess_window_classification import Preprocess

# %%
pre = Preprocess(file_dir='/ai/home/hanseok/sandbox/seminar/wikigold.conll.txt')

# %%
pre.sents[:3]
# Out:
# [[['<S>', 'O'],
#   ['<S>', 'O'],
#   ['010', 'I-MISC'],
#   ['is', 'O'],
#   ['the', 'O'],
#   ['tenth', 'O'],
#   ['album', 'O'],
#   ['from', 'O'],
#   ['Japanese', 'I-MISC'],
#   ['Punk', 'O'],
#   ['Techno', 'O'],
#   ['band', 'O'],
#   ['The Mad Capsule Markets', 'I-ORG'],
#   ['.', 'O'],
#   ['<E>', 'O'],
#   ['<E>', 'O']],
#  [['<S>', 'O'],
#   ['<S>', 'O'],
#   ['This', 'O'],
#   ['album', 'O'],
#   ['proved', 'O'],
#   ['to', 'O'],
#   ['be', 'O'],
#   ['more', 'O'],
#   ['commercial', 'O'],
#   ['and', 'O'],
#   ['more', 'O'],
#   ['techno-based', 'O'],
#   ['than', 'O'],
#   ['Osc-Dis', 'I-MISC'],
#   [',', 'O'],
#   ['with', 'O'],
#   ['heavily', 'O'],
#   ['synthesized', 'O'],
#   ['songs', 'O'],
#   ['like', 'O'],
#   ['Introduction 010', 'I-MISC'],
#   ['and', 'O'],
#   ['Come', 'I-MISC'],
#   ['.', 'O'],
#   ['<E>', 'O'],
#   ['<E>', 'O']],
#  [['<S>', 'O'],
#   ['<S>', 'O'],
#   ['Founding', 'O'],
#   ['member', 'O'],
#   ['Kojima Minoru', 'I-PER'],
#   ['played', 'O'],
#   ['guitar', 'O'],
#   ['on', 'O'],
#   ['Good Day', 'I-MISC'],
#   [',', 'O'],
#   ['and', 'O'],
#   ['Wardanceis', 'I-MISC'],
#   ['cover', 'O'],
#   ['of', 'O'],
#   ['a', 'O'],
#   ['song', 'O'],
#   ['by', 'O'],
#   ['UK', 'I-LOC'],
#   ['post', 'O'],
#   ['punk', 'O'],
#   ['industrial', 'O'],
#   ['band', 'O'],
#   ['Killing Joke', 'I-ORG'],
#   ['.', 'O'],
#   ['<E>', 'O'],
#   ['<E>', 'O']]]

# %%
pre.word_idx
# Out:
# {'bench': 0,
#  'food': 1,
#  'Anastasiya Vertinskaya': 4138,
#  'Beauford': 2,
#  'Don Wright': 3,
#  'You': 4139,
#  'using': 4,
#  'Advisory': 5,
#  'catch': 6,
#  'effort': 7,
#  'Ultimate Hockey': 3430,
#  'favorable': 9,
#  'streets': 10,
#  'eleven': 11,
#  'thirty': 4142,
#  'New York Stock Exchange': 12,
#  'BEL20': 13,
#  'families': 4838,
#  'indicating': 14,
#  'charts': 15,
#  'transformed': 16,
#  'scientific': 4145,
#  'Suite': 6169,
#  'favourite': 4146,
#  'Later': 4147,
#  'Irene Radford': 17,
#  'because': 4148,
#  'inspires': 18,
#  'majority': 19,
#  'Newcastle upon Tyne': 7682,
#  '1952': 20,
#  'Center for Science and Culture': 4140,
#  'nutrition': 23,
#  'border': 24,
#  'Israel': 25,
#  'He': 4150,
#  'Agotes': 4151,
#  'Friedrich von Schlegel': 26,
#  '11:00': 27,
#  'boosted': 28,
#  'AMEL': 30,
#  'Asebi': 8,
#  'opponent': 4152,
#  'recognised': 32,
#  'Prussian': 33,
#  'Bridgeton': 4154,
#  'listeners': 34,
#  'rules.': 4155,
#  'supporters': 35,
#  'teach': 36,
#  'Cards': 37,
#  'industrial-agricultural': 4157,
#  'Mistress to an Age': 4158,
#  '6/40': 41,
#  'powerful': 39,
#  'timber': 2036,
#  'Baseball Hall of Fame': 42,
#  'Belgrano': 44,
#  'shop': 45,
#  'Reading Festival': 46,
#  'bodies': 4163,
#  'currently': 2738,
#  'SWAT': 2038,
#  'LSWR': 4164,
#  'increasing': 1379,
#  'work': 47,
#  'extended': 48,
#  'Original': 50,
#  'UPI Lineman of the Year': 51,
#  'resurgence': 52,
#  'Formula 3': 53,
#  'regain': 1538,
#  'début': 54,
#  '1930s': 6893,
#  'province': 55,
#  '!': 5474,
#  'Korn': 56,
#  'Julian Cope': 58,
#  'translation': 7997,
#  'down': 4165,
#  'votes': 59,
#  'Fashion': 4166,
#  'Francis Crick': 60,
#  '88': 5478,
#  'young': 62,
#  'overtone': 4169,
#  'praising': 4170,
#  'William C. Cesaroni.': 63,
#  'CSHL': 64,
#  '[': 65,
#  'Glastonbury Festival': 7542,
#  '1974': 4171,
#  'Les Bains': 4172,
#  'Ilocos Sur': 7543,
#  'Diana Paxson': 4173,
#  'introduced': 66,
#  'gun': 4174,
#  'Surabaya': 4175,
#  'ETHEL': 67,
#  'John Abercrombie': 68,
#  'teenage': 69,
#  'yes': 70,
#  'composed': 4177,
#  'scenes': 71,
#  'release': 73,
#  'Li Shimin': 74,
#  'Buffalo Bisons': 4179,
#  'reconciliation': 75,
#  'register': 4180,
#  'inmates': 4181,
#  "L'Internationale": 4144,
#  'achieve': 4182,
#  'fanfare': 4183,
#  'criticism': 76,
#  'equal': 77,
#  'qualify': 79,
#  '$1.00': 80,
#  'strict': 4186,
#  'argued': 81,
#  'Ez2DJ 7th TraX - Resistance': 4187,
#  'diaspora': 82,
#  'roster': 3188,
#  'leader': 83,
#  'arguably': 5482,
#  'naturally': 84,
#  'guarantee': 4188,
#  'Samsung': 4189,
#  '1985': 4190,
#  'Sudden-death': 85,
#  'Hyatt Regency': 86,
#  'leading': 87,
#  'path': 88,
#  'pilgrim': 4193,
#  'campus': 6179,
#  'American Civil Liberties Union': 4194,
#  'lettermen': 89,
#  'Spirit Store': 90,
#  'Angelo Fresquet': 4877,
#  'careers': 7019,
#  'inspired': 91,
#  'self-taught': 92,
#  'Potosí': 4197,
#  'Battle of Gettysburg': 4198,
#  'cerebrum': 4199,
#  'efforts': 94,
#  'Mendonça': 4200,
#  'Indian': 95,
#  'irony': 6183,
#  'seem': 4201,
#  'dolomite': 96,
#  'Perth': 4203,
#  'Solon Bixler': 4205,
#  'Falcons': 4206,
#  'music': 97,
#  'Danish': 4208,
#  'propensity': 1573,
#  'windows': 4209,
#  'course': 98,
#  'Shakira': 4211,
#  'Piano': 4212,
#  'Adam Mickiewicz': 99,
#  'szlachta': 100,
#  'point': 102,
#  'boosts': 22,
#  'Culverthorpe Estate': 4215,
#  'scientists': 8136,
#  'lbs': 3446,
#  'CBC': 4216,
#  'Developing': 103,
#  'Mojave': 7949,
#  'component': 104,
#  '1918': 105,
#  'Herbert A E Scheele Obe': 4217,
#  'ranks': 4218,
#  'masters': 4219,
#  'literature': 4149,
#  'Dahvin " DaHv " Daniels': 4220,
#  'missing': 6232,
#  'store': 106,
#  'managed': 107,
#  'chain': 4222,
#  'December': 108,
#  'accident': 109,
#  'South African': 4224,
#  'developers': 4225,
#  'society': 4226,
#  'such': 4854,
#  'Carnegie Institution': 7205,
#  'Then': 4227,
#  'developmental': 4228,
#  'patriotism': 4229,
#  'Clinical Hospital Mostar': 110,
#  'Crawdaddy': 111,
#  'Atlantic City': 4230,
#  'ban': 112,
#  'X86-based': 6186,
#  '15.8': 113,
#  'there': 4233,
#  'neighbourhood': 8056,
#  'Trestles': 4234,
#  'exhausted': 4235,
#  'MTV2': 4236,
#  'Singapore': 4240,
#  'surrender': 4241,
#  'prodigies': 1395,
#  'Sønderbor County': 116,
#  'Under-19s': 4244,
#  'installed': 6188,
#  'gaining': 117,
#  '$2': 4246,
#  'vacated': 4247,
#  'Phillips House': 2749,
#  'Li Rois Adenes': 4248,
#  'followed': 119,
#  'websites': 4250,
#  'Place': 121,
#  'Hungary': 122,
#  'figure': 4252,
#  'pounds': 123,
#  'Flanders Fields': 124,
#  '1825': 125,
#  'forms': 126,
#  'Cahets': 127,
#  'scored': 128,
#  'Adolescent Life Coaching Center': 129,
#  'argument': 130,
#  'crossing': 131,
#  'electronica': 132,
#  '1818-1896': 7548,
#  'album': 133,
#  'puncher': 4257,
#  'becomes': 135,
#  'Africa': 1397,
#  'watchdog': 136,
#  'lush': 31,
#  'Catch the flow': 4258,
#  '2005': 4259,
#  'twists': 137,
#  'classic': 2050,
#  'winning': 4260,
#  'almighty': 713,
#  'earlier': 7410,
#  'climbing': 138,
#  'introverted': 4261,
#  'documented': 140,
#  'decided': 3449,
#  'Aufklarung': 4262,
#  'first': 4263,
#  'bearing': 141,
#  'very': 142,
#  'Heydour': 144,
#  'certain': 145,
#  'approachable': 4265,
#  'DJs': 3451,
#  'lumber': 7961,
#  'Keim': 4268,
#  'earthen': 147,
#  'thermal': 148,
#  'then-declining': 4270,
#  'younger': 6190,
#  'coverage': 4271,
#  'ACLU': 149,
#  'Al Kavelin': 150,
#  'so': 4272,
#  'suicides': 151,
#  'headed': 152,
#  'come': 153,
#  'née': 7550,
#  'showed': 6192,
#  'analogue': 4273,
#  'counter': 4274,
#  'Liberal Party': 155,
#  'red': 4156,
#  'cross': 4137,
#  'Union': 4276,
#  "Dillard 's": 4278,
#  'Dou Jiande': 4280,
#  'Eugenics Record Office': 4281,
#  'post-Ceauşescu': 156,
#  'Kanye West': 4282,
#  'compared': 4283,
#  'unchanged': 158,
#  'thing': 1088,
#  'village': 159,
#  'Steele Prize': 4288,
#  'Davis Gym': 160,
#  'Veterans Day': 161,
#  '2009': 162,
#  'strong': 163,
#  'assault': 165,
#  'Aftermath Records': 5491,
#  'RTÉ': 4290,
#  'rover': 7177,
#  'Maratha': 4291,
#  'Knowing': 167,
#  'Flat': 168,
#  'arrangements': 6363,
#  'Inexplicably': 169,
#  'Rawlins': 4293,
#  'arpeggios': 4294,
#  'review': 4295,
#  'behind': 172,
#  'moral': 173,
#  'scoreless': 174,
#  'closed': 4298,
#  'Southern Cross Broadcasting': 4299,
#  'Panaji': 4300,
#  'primarily': 175,
#  'daily': 176,
#  'demo': 177,
#  'One': 178,
#  'Octobe': 4304,
#  'Bela Fleck and the Flecktones': 181,
#  'Retreating': 4305,
#  'Poolesville': 182,
#  'Cameo Theatre': 717,
#  'shutdown': 43,
#  'raise': 184,
#  'assessment': 185,
#  'Atlantic City Railroad': 4306,
#  'roughly': 186,
#  'Aero Gare': 187,
#  'Gerry Kelly': 4308,
#  'Swiss Super League': 188,
#  '12': 6670,
#  'would': 4309,
#  'towards': 189,
#  'Avenged Sevenfold': 190,
#  'Radio': 4311,
#  'merger': 192,
#  'composer': 719,
#  'Gibson City': 193,
#  'Patriot League': 194,
#  'confrontation': 195,
#  'defender': 196,
#  'satisfaction': 198,
#  'Physiology': 199,
#  '1923': 7127,
#  'banquets': 5494,
#  'First': 6199,
#  'stores': 4869,
#  'top': 4314,
#  'The Times Literary Supplement': 4315,
#  'channels': 5496,
#  'recording': 200,
#  'tracks': 201,
#  'Concerts': 202,
#  '18th': 1834,
#  'retained': 598,
#  'S': 6908,
#  'Results': 204,
#  'granted': 6200,
#  'transferred': 205,
#  'broad-based': 4871,
#  'Erwin Gutawa': 206,
#  'Rhine': 6201,
#  'Market': 207,
#  'legacy': 4319,
#  'American College of Obstetricians and Gynecologists': 208,
#  'symphony': 209,
#  'tsunami': 210,
#  'barrels': 4874,
#  'round': 211,
#  'grown': 4321,
#  'serial': 4325,
#  'plan': 212,
#  'forested': 4326,
#  '8,500': 4162,
#  'Alfredo Keil': 213,
#  'fatally': 4327,
#  'stress': 214,
#  'natives': 4328,
#  'argent': 215,
#  'World Bodyboarding Tour': 216,
#  'Beretta 9mm': 4329,
#  'situations': 6205,
#  'additional': 4330,
#  'Since': 4331,
#  'institutions': 4332,
#  'facilities': 3463,
#  'DJ': 218,
#  'A Song of Love and Death': 219,
#  'spammer': 221,
#  'Jenny Seaton': 5486,
#  'union': 222,
#  'yard': 728,
#  'Diamond Horseshoe': 4336,
#  'ill': 7558,
#  'conjunction': 223,
#  'marine': 2065,
#  '4-0': 4340,
#  'umpire': 224,
#  'Deadsy': 225,
#  'further': 226,
#  'wood': 230,
#  'embraces': 3843,
#  'Lord Stanley': 231,
#  '2005/2006': 49,
#  'DefamationAction.com': 232,
#  'monarchist': 7753,
#  'composing': 233,
#  'production': 4344,
#  'Poet': 234,
#  'aviation': 236,
#  'Welcome': 237,
#  'insists': 4345,
#  'pistol': 4346,
#  'riding': 240,
#  "Nicholson 's": 243,
#  'celebrity': 6405,
#  'Dr. Nner': 4349,
#  'deportation': 4350,
#  'That': 244,
#  'near': 245,
#  'Eddy Duchin': 6212,
#  'campuses': 7990,
#  'awards': 4352,
#  'Approved': 6911,
#  'Street Drum Corps': 4353,
#  'convened': 246,
#  '010': 247,
#  'installments': 249,
#  'narrowcast': 4355,
#  'New Hampshire': 250,
#  'municipality': 251,
#  'Le Loft & Dunes': 7865,
#  'Ben': 4357,
#  'schoolboy': 5502,
#  'During': 4358,
#  'admitted': 57,
#  'Before': 252,
#  'Including': 4359,
#  'language': 4360,
#  'multi-state': 2766,
#  'Compiègn': 255,
#  'kick-starting': 256,
#  'identity': 4362,
#  'No. 18': 257,
#  'facts': 4363,
#  'VFL': 4364,
#  'poles': 4365,
#  'extremely': 258,
#  'The Hockey News': 4367,
#  'feminine': 6216,
#  'bronze': 4368,
#  'cash': 4369,
#  'launch': 260,
#  'Immigration Act of 1924': 4370,
#  'harboured': 4371,
#  'Soviet Union': 261,
#  'follow': 4372,
#  'Old': 4373,
#  'competing': 262,
#  'psychiatry': 263,
#  'State Route 267': 4375,
#  'news': 265,
#  'South Korean': 7566,
#  'mestizo': 4376,
#  'card': 266,
#  'role': 4377,
#  'Havant': 267,
#  'manager': 268,
#  'Angelo': 4378,
#  'commemorates': 269,
#  'NAACP': 4379,
#  'Nadja Angelique Beauford': 4381,
#  'biography': 5764,
#  'Fairfax County': 5303,
#  'inducted': 4167,
#  'horizontal': 271,
#  'aided': 4384,
#  'innovative': 272,
#  'SAFRA Radio': 4386,
#  '2%': 273,
#  'musician': 61,
#  'connects': 4388,
#  'Cold Spring Harbor': 8063,
#  'pretext': 274,
#  'hi-fi': 4389,
#  'starter': 275,
#  'lung': 4391,
#  'interaction': 4885,
#  'pointed': 276,
#  'Billy Daniels': 277,
#  'POLE': 6218,
#  'eye': 4392,
#  'fellow': 6916,
#  'dynamics': 279,
#  'Graham Mabury': 4393,
#  'sanctity': 4395,
#  'Motto': 4396,
#  'CBS , Inc.': 280,
#  'AIDS': 281,
#  'municipalit': 282,
#  'touched': 283,
#  'Grantham': 284,
#  'viewership': 286,
#  'Year': 4398,
#  'sport': 287,
#  'consisted': 4399,
#  '1891': 288,
#  'Faith': 4400,
#  'Church of Our Lady of Compassion': 289,
#  'last': 290,
#  'Newell H. Beaty': 4401,
#  'wretched': 5510,
#  'initial': 291,
#  'towns': 4402,
#  'policies': 3943,
#  'establish[ing': 4403,
#  'demolished': 4404,
#  'gravity': 4405,
#  'Kennett': 293,
#  'loans': 294,
#  'anniversary': 4407,
#  'Program': 4409,
#  'producer': 295,
#  'Graduated': 296,
#  'murkier': 298,
#  'four-year': 299,
#  'Fresquito Fresquet': 4410,
#  'Sound Transit': 301,
#  'winner': 302,
#  'against': 5512,
#  'association': 4411,
#  'save': 7355,
#  'doing': 5513,
#  'All-American': 303,
#  'despite': 304,
#  'acres': 5517,
#  'antenna': 305,
#  'Glenn A. Profitt II': 4412,
#  'five': 306,
#  '1830': 307,
#  'under-16s': 2077,
#  'Cascade Timberlands': 4414,
#  'Ken Norton': 308,
#  'caucus': 1416,
#  'various': 309,
#  'Victor Wooten': 4416,
#  'your': 4417,
#  'officer': 4418,
#  'wedging': 4419,
#  'minister': 310,
#  'Portchester': 6922,
#  'pornography': 4421,
#  'rise': 4422,
#  'Lougou': 2779,
#  '65 Air Division ( Defense )': 311,
#  'cooperated': 312,
#  'pitch': 313,
#  'fans': 4424,
#  'long-term': 315,
#  'Tony Pooley': 4427,
#  'pilgrimages.': 318,
#  'Karl Langdon': 319,
#  'expansion': 320,
#  'supply': 323,
#  'ways': 322,
#  'Metrobus': 324,
#  'Madame de Staë': 4428,
#  '34th': 325,
#  'High': 327,
#  'affairs': 328,
#  'Paris Hilton': 4430,
#  'dual': 4431,
#  'anyway': 4432,
#  'Watson School of Biological Sciences': 4433,
#  'Duane Bobick': 6223,
#  'magazines': 329,
#  'Danube': 4435,
#  'vision': 7575,
#  'video': 6593,
#  'effector': 4436,
#  'sinking': 4437,
#  'available': 330,
#  'defense': 331,
#  'flat': 332,
#  'although': 333,
#  'Aabenraa County': 334,
#  'Florida': 742,
#  'film': 3483,
#  'youth': 4178,
#  'spirit': 4891,
#  'Chick Corea': 335,
#  'self-contained': 336,
#  'detached': 337,
#  'Athens': 4440,
#  'house': 4441,
#  'doubled': 4442,
#  'colleague': 339,
#  'Adelaide': 340,
#  'then': 4443,
#  'Canards': 342,
#  'bears': 343,
#  'burying': 344,
#  'Hey': 5520,
#  'Wheat': 4445,
#  'receptacle': 345,
#  'generated': 346,
#  'fitted': 4446,
#  'interest': 347,
#  'There': 348,
#  'luthier': 349,
#  'continuing': 5521,
#  'program': 4448,
#  'Seth MacFarlane': 4449,
#  'enough': 4450,
#  'occupants': 350,
#  'lying': 351,
#  'Established': 352,
#  'Frédéric Diefenthal': 353,
#  'radar': 4452,
#  'Mark Hopkins Hotel': 6636,
#  'Red Men': 354,
#  'literary': 4454,
#  'Debden': 2780,
#  '170': 7457,
#  'postdoctoral': 3488,
#  'resigned': 4456,
#  'regard': 356,
#  'AGS JH21': 4457,
#  'hi-hat': 357,
#  'businessman': 358,
#  'heavyweight': 359,
#  'County': 4459,
#  'talkback': 360,
#  'West Coast Eagles AFL': 362,
#  'looking': 7578,
#  'Teófil Stevenson': 4184,
#  'author': 364,
#  'protection': 6931,
#  '38-0': 365,
#  'tourists': 1756,
#  'Градский': 4461,
#  'track': 6229,
#  'non-union': 366,
#  '1911': 4463,
#  'And': 2083,
#  '846': 4464,
#  '197': 367,
#  '0': 368,
#  'eleventh': 369,
#  'Now': 4465,
#  'Maxfield Parrish': 4466,
#  'end': 370,
#  'evolved': 4468,
#  'will': 4185,
#  '38': 4470,
#  '1932': 2782,
#  'Caribbean': 372,
#  '2,700,000': 4472,
#  'tiebreaker': 373,
#  'Defamation Action League': 2086,
#  'pianist': 2784,
#  'numerous': 4473,
#  'Rebuilding': 374,
#  'Hall': 4474,
#  'Stylistically': 376,
#  'contact': 4476,
#  'Manuel Ramos': 377,
#  'pest': 378,
#  'Space': 379,
#  'threw': 4896,
#  'injects': 380,
#  'Mystic Dream 9903': 6349,
#  'hours': 381,
#  '1937': 382,
#  'Cyrillic': 2418,
#  '20-something': 383,
#  'believe': 384,
#  'Electric Avenue': 385,
#  'CPZ': 4480,
#  'Hockey Hall of Fame': 386,
#  'Sarraounia': 388,
#  'meetings': 4482,
#  'listings': 389,
#  '41-42': 390,
#  'aims': 393,
#  'sponsored': 392,
#  'Hans Wieck': 394,
#  'ball': 4485,
#  'philosophy': 395,
#  'assets': 4486,
#  '10.5': 397,
#  'Palestinian National Liberation League': 398,
#  'scientist': 4487,
#  'fall': 399,
#  'Mott': 400,
#  '1799': 4488,
#  'both': 401,
#  'taken': 4490,
#  'Club BED': 4491,
#  'guys': 404,
#  'expedition': 4493,
#  'Darkness': 4494,
#  'environmentally': 405,
#  'electric': 406,
#  'See': 6079,
#  'ruthlessly': 6235,
#  'Roskilde': 4496,
#  'centre': 4497,
#  'Azeby': 407,
#  'railroad': 408,
#  'Patrick Stewart': 4498,
#  'Morey': 4500,
#  'Sports Today': 6933,
#  'results': 4501,
#  'difficult': 409,
#  'readers': 4502,
#  '[1': 4503,
#  'stacked': 316,
#  'skipping': 5529,
#  'marching': 4504,
#  'Dynamic': 2792,
#  'World Anti-Communist League': 1425,
#  'outperformed': 4505,
#  'list': 7583,
#  'constructed': 4506,
#  'instituted': 4507,
#  'vacate': 410,
#  'right-handed': 4508,
#  'probability': 4509,
#  'John Locke': 4510,
#  'Ricky Martin': 411,
#  'League': 4512,
#  'Campaign of Alto Perú': 7584,
#  'tackle': 4513,
#  'provincial': 5508,
#  'circle': 413,
#  'horticultural': 414,
#  '.His': 4514,
#  'Citrone': 4515,
#  'Judaism': 415,
#  'separated': 4516,
#  'biology': 5532,
#  'south-east': 416,
#  'nineties': 417,
#  'change': 4517,
#  'intermarried': 4518,
#  'Alabama': 4519,
#  'where': 4520,
#  'Starting': 4521,
#  'headquarters': 4522,
#  'However': 4523,
#  'Aguano': 419,
#  'successive': 4524,
#  'island': 4525,
#  'full-time': 421,
#  'exchanged': 751,
#  'spite': 4526,
#  'eugenicists': 8064,
#  'jurors': 4527,
#  'connected': 5535,
#  'peers': 6740,
#  'Descendant': 4528,
#  'shooting': 423,
#  'Kitzmiller': 3501,
#  'Jimmy Manopo Band': 424,
#  'crown': 4530,
#  'limited': 426,
#  'A Storm to Come': 2800,
#  'ranges': 4531,
#  'Jesse Auton': 427,
#  'commercials': 4192,
#  'Dipavati': 4532,
#  'maximize': 429,
#  'Indonesian': 6241,
#  'produces': 4533,
#  'tributary': 430,
#  '1896': 4534,
#  'starring': 4535,
#  'including': 5537,
#  'folding': 431,
#  'printed': 4537,
#  'sites': 433,
#  'swell': 435,
#  'quoted': 2039,
#  'in-state': 4538,
#  'doses': 4539,
#  'Coronado Unified School District': 6242,
#  'agent': 6938,
#  'routes': 3505,
#  'Kreis Apenrade': 436,
#  'Box': 5646,
#  'industries': 754,
#  'Valhalla': 437,
#  'Germans': 4541,
#  'activists': 439,
#  'Schelling': 7440,
#  'ice': 4542,
#  'roll': 4543,
#  'sum': 4544,
#  'hold': 1564,
#  'Eas Timor': 4545,
#  'Devonian': 441,
#  'unpopularity': 442,
#  '883JIA FM': 443,
#  'populations': 4547,
#  'detainees': 4548,
#  '43': 6941,
#  'Peace River': 445,
#  'John Near': 4549,
#  'German Europe': 440,
#  'knocked': 447,
#  'PlazaCenter': 4551,
#  'matches': 4195,
#  'secret': 5710,
#  '2008-2010': 4552,
#  'sisperse': 448,
#  '19': 449,
#  'reinforcement': 450,
#  'wooded': 4554,
#  'debuted': 4555,
#  'included': 4556,
#  'system': 453,
#  '13th Floor': 4559,
#  'Leadership': 454,
#  'remixers': 455,
#  'places': 4561,
#  'Tangerine Dream': 4562,
#  'capture': 4563,
#  '2': 6525,
#  'fully': 456,
#  'roadway': 457,
#  '1926': 6243,
#  'oxidizing': 4564,
#  'Normandy': 458,
#  'I Dewa Gede Budjana': 459,
#  'copper': 460,
#  'deep': 7976,
#  'mess': 4820,
#  'legs': 4566,
#  '500,000,000': 4196,
#  'matter': 4567,
#  'Her': 4568,
#  'West Coastway Line': 4569,
#  'Catholic': 461,
#  'Third Reich': 4570,
#  'Kevin Cash': 6530,
#  'estimate': 462,
#  'fatal': 463,
#  '-': 464,
#  'Founded': 5544,
#  'concert': 4573,
#  'stops': 466,
#  'Manuel Belgrano': 4575,
#  '9/23/06': 467,
#  'Calabi': 468,
#  'alongside': 4577,
#  'wounds': 469,
#  'contention': 471,
#  'Toshiba-EMI': 93,
#  'Maryland': 472,
#  'holiday': 2106,
#  'Mills': 473,
#  'frame': 4579,
#  'response': 474,
#  'exist': 475,
#  'spent': 5545,
#  'Construction': 476,
#  'American Scientific Affiliation': 477,
#  'A-League': 478,
#  'translate': 4581,
#  'Tarzan corner': 4582,
#  'surgery': 4583,
#  'memory': 4584,
#  'phoning': 479,
#  'struck': 4586,
#  'anatomist': 480,
#  'The Shining': 481,
#  'overcome': 4589,
#  'relocated': 482,
#  'Bungalow': 483,
#  'asked': 4591,
#  'operations': 4593,
#  'participated': 1435,
#  'Jacksonville Suns': 4594,
#  'matrix': 4595,
#  'entertainment': 484,
#  'Bridgton Hinkleys': 762,
#  'slut': 4598,
#  'countryman': 6953,
#  'NASCAR 2002': 485,
#  'pencil': 4599,
#  'mixture': 6246,
#  '45': 486,
#  'octavs': 7968,
#  'planned': 6247,
#  'loss': 487,
#  'bankrolled': 7796,
#  'begun': 488,
#  'Carter': 4919,
#  'founder': 489,
#  'Scouts': 2813,
#  'Places': 4601,
#  'crushed': 4602,
#  'really': 4603,
#  '2003': 4604,
#  'dance': 4605,
#  'accepting': 4606,
#  'ordinary': 4607,
#  'total': 2111,
#  'vegetable': 4921,
#  'John Wintermeyer': 491,
#  '11,448': 4609,
#  'James W. Hoyt': 492,
#  'Shree Dwarkeshwar': 493,
#  '310,089': 494,
#  'oncologist': 495,
#  'perform': 496,
#  'exception': 4610,
#  'John A. Corder': 4611,
#  'Australians Against Further Immigration': 4612,
#  'To': 6952,
#  'rapper': 6638,
#  'Wren': 498,
#  '2-0': 4613,
#  'Schools': 6342,
#  'issue': 499,
#  'attached': 500,
#  'profits': 501,
#  'tightly': 502,
#  '6th': 4614,
#  'phrase': 503,
#  'extends': 4202,
#  'heavily': 504,
#  'Sunday': 7596,
#  'carbon': 505,
#  'Game': 506,
#  'Campbell , A.A.': 6285,
#  'desert': 4617,
#  'Datecs MP500': 4204,
#  'Count': 4618,
#  'Held': 4619,
#  'Dec.': 5791,
#  'offline': 6959,
#  'west': 432,
#  'changes': 1444,
#  '"': 507,
#  'property': 508,
#  'expressed': 4621,
#  'inadvisable': 4622,
#  'east': 4623,
#  'phase': 4624,
#  'functionaries': 4625,
#  'Bangladesh Boy Scout Association': 4626,
#  'Devil Ray': 7598,
#  'MAC East': 509,
#  'executed': 510,
#  'fonts': 511,
#  'caps': 4628,
#  'stronger': 2122,
#  'Canadian': 771,
#  'motto': 4630,
#  'attract': 4631,
#  'integrity': 515,
#  'Montreal Hockey Club': 4207,
#  'San Francisco': 516,
#  'active': 4633,
#  'triple': 4634,
#  'British Columbia Institute of Technology': 4635,
#  'blaze': 7247,
#  'day-age': 517,
#  'Michael Behe': 518,
#  'honor': 4637,
#  'painters': 519,
#  'maintaining': 520,
#  'pro-life': 4640,
#  'Marlboro Masters': 521,
#  'October': 4641,
#  'during': 4642,
#  'Armand': 522,
#  'styles': 4643,
#  'April': 523,
#  'escape': 4644,
#  'electron': 8030,
#  'voiced': 4645,
#  "Nicholson 's Limited": 6965,
#  'Killing Joke': 524,
#  'Sattler': 4646,
#  'other': 4647,
#  'class': 4648,
#  'commanding': 525,
#  'Fairfax Connector': 4210,
#  'containing': 4649,
#  'short': 526,
#  'July': 527,
#  'supportive': 4650,
#  'airspace': 4651,
#  'MAC': 4652,
#  'Mece': 4654,
#  'exercising': 4655,
#  'cortex': 4656,
#  'needs': 4658,
#  '1966': 4659,
#  'Lee Tate': 529,
#  'imported': 777,
#  'Mozarts': 5553,
#  'Senckenberg Museum': 6954,
#  ...}

# %%
pre.look_up.shape
# Out:
# (10, 8157)

# %%
window_size = pre.window_size
word_dim = pre.word_dim
window_dim = window_size*2 + 1
hidden_dim = 10

# %%
def get_window_vector(words): # words = 2w+1 word
    global window_size
    x = []
    for word in words:
        x.extend(pre.look_up[:,pre.word_idx[word[0]]])
    words_c = words.copy()
    while words_c[window_size][1] == 'I-LOC':
        random.shuffle(words_c)
    x_c = []
    for word in words_c:
        x_c.extend(pre.look_up[:,pre.word_idx[word[0]]])
    x = np.array(x).reshape(len(x), 1) # 10, -> 10, 1
    x_c = np.array(x_c).reshape(len(x_c), 1)
    return x, words, x_c, words_c

# %%
def feedforward(x, x_c):
    global W, U, b
    z = np.dot(W, x) + b
    z_c = np.dot(W, x_c) + b
    a = expit(z)
    a_c = expit(z_c)
    s = np.dot(U.transpose(), a)
    s_c = np.dot(U.transpose(), a_c)
    return z, a, s, z_c, a_c, s_c

# %%
def backprop():
    global W, U, b
    global x, z, a, s, x_c, z_c, a_c, s_c
    dU, dU_c = a, a_c
    error = np.multiply(U, np.multiply(expit(z), 1-expit(z))) # np.multiply(A, B) <=> For all i, a_i * b_i
    error_c = np.multiply(U, np.multiply(expit(z_c), 1-expit(z_c)))
    dW = np.dot(error, x.transpose()) # np.dot(A, B) <=> Inner product of A and B
    dW_c = np.dot(error_c, x_c.transpose())
    db = error
    db_c = error_c
    dx = np.dot(W.transpose(), error)
    dx_c = np.dot(W.transpose(), error_c)
    return dU, dW, db, dx, dU_c, dW_c, db_c, dx_c

# %%
def update():
    global U, W, b, dU, dW, db, dU_c, dW_c, db_c, learning_rate
    U -= learning_rate * (-dU + dU_c)
    W -= learning_rate * (-dW + dW_c)
    b -= learning_rate * (-db + db_c)
    return U, W, b

# %%
def update_lookup():
    global word, word_c, pre, word_dim, x, x_c, dx, dx_c, learning_rate
    look_up = np.copy(pre.look_up)
    for n, pair in enumerate(word):
        n_c = word_c.index(pair)
        target_dx = dx[n*word_dim:(n+1)*word_dim].reshape(word_dim,)
        target_dx_c = dx_c[n_c*word_dim:(n_c+1)*word_dim].reshape(word_dim,)
        look_up[:,pre.word_idx[pair[0]]] -= learning_rate * (-target_dx + target_dx_c) 
    return look_up

# %%
W = np.random.normal(loc=0, scale=0.5, 
                     size=(hidden_dim, window_dim*pre.word_dim))
U = np.random.normal(loc=0, scale=0.5, size=(hidden_dim, 1))
b = np.random.normal(loc=0, scale=0.5, size=(hidden_dim, 1))

# %%
W.shape, U.shape, b.shape
# Out:
# ((10, 50), (10, 1), (10, 1))

# %%
W_old, U_old, b_old, look_up_old = np.copy(W), np.copy(U), np.copy(b), np.copy(pre.look_up)

# %%
look_up_old[:,pre.word_idx['UK']]
# Out:
# array([ 1.38104121, -0.36026122,  0.5625093 , -0.72992135, -0.15014624,
#        -0.87295697,  1.29532456, -0.3446441 , -1.90868303, -0.74725082])

# %%
print(W)
print(U)
print(b)
# Out:
# [[  2.43200332e-01   6.76929703e-01   8.86985031e-02   5.16660075e-01
#    -1.55152978e-01  -5.06688708e-02  -3.24277388e-01  -1.04097893e-02
#    -2.19701041e-01   1.69051685e-01  -1.10132669e-01   6.51976065e-02
#     4.03210139e-01   5.90684117e-01  -4.91265565e-01   2.37408359e-01
#    -1.16821098e-01  -6.37384093e-01  -2.85391082e-01   3.10446757e-01
#     3.43354243e-01   3.98176800e-01   6.80154727e-02  -3.90165628e-01
#    -5.05090262e-01  -2.48118912e-01   2.71693450e-01  -9.88097087e-02
#     5.32333560e-01  -4.81993580e-01   2.72004487e-01  -6.77590064e-01
#     6.38265847e-02  -6.04214617e-01   2.11728440e-01  -1.63654750e-01
#    -3.23491088e-01   1.89022070e-01   2.60317616e-01   1.10302022e-01
#    -3.73982974e-01  -7.00924200e-01   4.02302199e-01   2.72390347e-01
#    -1.02078373e-01   3.71892337e-01   1.44547256e-01  -3.49748407e-01
#    -2.40694211e-01   1.34762755e-01]
#  [ -2.52445856e-03   2.63402910e-01  -9.44116439e-01  -6.53720212e-01
#     4.29362739e-01  -6.37495560e-01   2.93187599e-01   5.56586152e-01
#  [ 0.324231  ]
#  [-0.58476676]
#  [-0.64209108]
#  [ 0.51073396]
#  [ 1.26246086]]

# %%
learning_rate=0.1
epoch = 20

# %%
for t in range(epoch):
    pprint("[%d/%d]" % (t+1, epoch))
    J_pass, J_count = 0, 0
    for sent in pre.sents:
        for n in range(len(sent) - pre.window_size*2):
            nums = [n+i for i in range(pre.window_size*2+1)]
            words = [sent[num] for num in nums]
            if words[pre.window_size][1] != 'I-LOC':
                continue
            x, word, x_c, word_c = get_window_vector(words)
            z, a, s, z_c, a_c, s_c = feedforward(x, x_c)
            J = max(0, 1 - s[0][0] + s_c[0][0])

            J_count += 1
            if J > 0:
                dU, dW, db, dx, dU_c, dW_c, db_c, dx_c = backprop()
                U, W, b= update()
                pre.look_up = update_lookup()
            else:
                J_pass += 1
                continue
    pprint("%d / %d" % (J_pass, J_count))
# Out:
# '[1/20]'
# '564 / 1014'
# '[2/20]'
# '734 / 1014'
# '[3/20]'
# '795 / 1014'
# '[4/20]'
# '853 / 1014'
# '[5/20]'
# '868 / 1014'
# '[6/20]'
# '883 / 1014'
# '[7/20]'
# '906 / 1014'
# '[8/20]'
# '925 / 1014'
# '[9/20]'
# '919 / 1014'
# '[10/20]'
# '923 / 1014'
# '[11/20]'
# '941 / 1014'
# '[12/20]'
# '931 / 1014'
# '[13/20]'
# '951 / 1014'
# '[14/20]'
# '943 / 1014'
# '[15/20]'
# '943 / 1014'
# '[16/20]'
# '962 / 1014'
# '[17/20]'
# '965 / 1014'
# '[18/20]'
# '970 / 1014'
# '[19/20]'
# '968 / 1014'
# '[20/20]'
# '973 / 1014'

# %%
pre.look_up[:,pre.word_idx['UK']]
# Out:
# array([ 1.92266745,  0.65821441,  0.56778065, -2.15965321, -0.18903798,
#        -0.87155705,  1.47740683, -1.01838206, -0.97944603, -0.57275121])

# %%
print(W)
print(U)
print(b)
# Out:
# [[-0.54678644  1.1465987  -0.51765668 -0.24567722  1.01976957 -1.10536732
#   -0.21756396 -0.74293868  0.53323297 -0.80530814 -2.37564963 -0.0715684
#    1.25015666  1.09819217  0.10817743 -0.56291918 -1.10036713 -0.32921334
#    0.17980226  0.58243646  0.35454741  1.96639962  0.63510313 -2.68920088
#   -1.21624252 -0.76542782 -0.07046284 -1.09132623  2.09807814 -0.07529415
#    0.24535771 -1.55210567 -0.76731511  0.51996708 -0.11912168  0.66971634
#    0.05624902  0.15474465  1.59063026  1.01563783  0.06493863 -0.11745417
#   -0.0457221   0.16944778 -0.54450902  0.08227546 -0.50382554 -0.36925855
#    1.32323487 -0.4389935 ]
#  [-0.2554074  -0.05455256 -1.29694532 -0.76692052  0.08824678 -0.45115434
#   -0.3754048   1.2319611   1.22499434 -0.50818254  0.26037529  0.28981754
#    0.63749331 -0.65032219 -0.57636648  0.02738162 -0.28987779 -1.00066895
#   -1.70040838  0.20782449  1.02962504  1.05125849 -0.02155495 -0.93429029
#    0.7688841  -0.27348878  0.45277341 -0.30408077  1.39101052  0.05470791
#   -0.94134239 -0.33142684  0.72512884  0.02862599  0.36270146 -0.03459609
